# %%
import pandas as pd
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
import numpy as np

# %%
start = datetime.datetime(2018,1,1)
end = datetime.datetime(2021,12,12)

# %%
# This will get the data for 3 companies
# It can be modified by changing each company name
# In this example it is reading the Tesla, Ford and GM Stock using DataREader
tesla  = web.DataReader("TSLA",'yahoo',start,end)
toyota = web.DataReader("TM",'yahoo',start,end)
gm = web.DataReader("GM",'yahoo',start,end)

# %%
#Save the stock information in the CSV
tesla.to_csv('Tesla_Stock_20180101_20211212.csv')
toyota.to_csv('Toyota_Stock_20180101_20211212.csv')
gm.to_csv('GM_Stock_20180101_20211212.csv')

# %%
# Read Tesla data
tesla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2018-01-02  64.421997  62.200001  62.400002  64.106003  21761000.0  64.106003
# 2018-01-03  65.050003  63.110001  64.199997  63.450001  22607500.0  63.450001
# 2018-01-04  63.709999  61.136002  62.574001  62.924000  49731500.0  62.924000
# 2018-01-05  63.448002  62.400002  63.324001  63.316002  22956000.0  63.316002
# 2018-01-08  67.403999  63.099998  63.200001  67.281998  49297000.0  67.281998

# %%
# Read Ford data
toyota.head()
# Out:
#                   High         Low        Open       Close  Volume   Adj Close
# Date
# 2018-01-02  128.429993  127.169998  127.430000  128.369995   83500  128.369995
# 2018-01-03  130.240005  128.559998  128.679993  130.130005  162200  130.130005
# 2018-01-04  132.160004  131.300003  131.309998  132.160004  161800  132.160004
# 2018-01-05  133.869995  133.080002  133.110001  133.860001  135300  133.860001
# 2018-01-08  134.789993  133.619995  133.979996  134.770004  131200  134.770004

# %%
# Read GM data
gm.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2018-01-02  41.869999  41.150002  41.240002  41.799999   6934600.0  38.072212
# 2018-01-03  42.950001  42.200001  42.209999  42.820000  14591600.0  39.001247
# 2018-01-04  44.250000  43.009998  43.090000  44.139999  17298700.0  40.203522
# 2018-01-05  44.639999  43.959999  44.500000  44.009998   9643300.0  40.085117
# 2018-01-08  44.590000  43.520000  44.040001  44.220001  13099600.0  40.276390

# %%
#Comparing the Open prices for each of the companies and create the plot
#Options are High,Low,Open,Close,Volume
tesla['Open'].plot(label='Tesla',figsize=(20,10))
toyota['Open'].plot(label='Toyota')
gm['Open'].plot(label='GM')
plt.ylabel('Stock Price')
plt.title('Stock Prices for Tesla, GM and Toyota')
plt.legend() # To put a legend for it
plt.show()

# %%
#Comparing the Volume for each of the companies and create the plot
tesla['Volume'].plot(label='Tesla',figsize=(20,10))
toyota['Volume'].plot(label='Toyota')
gm['Volume'].plot(label='GM')
plt.ylabel('Volume')
plt.title('Stock Prices for Tesla, GM and Toyota')
plt.legend() # To put a legend for it
plt.show()

# %%
#This will create columntal amount of money traded for each company
#To Calculate it will multiply Open price by the volume
tesla['Total Traded'] = tesla ['Open'] * tesla ['Volume']
toyota['Total Traded'] = toyota ['Open'] * toyota ['Volume']
gm['Total Traded'] = gm ['Open'] * gm ['Volume']

# %%
#now showing head and it will add a column to the the table for Total Traded
tesla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2018-01-02  64.421997  62.200001  62.400002  64.106003  21761000.0  64.106003
# 2018-01-03  65.050003  63.110001  64.199997  63.450001  22607500.0  63.450001
# 2018-01-04  63.709999  61.136002  62.574001  62.924000  49731500.0  62.924000
# 2018-01-05  63.448002  62.400002  63.324001  63.316002  22956000.0  63.316002
# 2018-01-08  67.403999  63.099998  63.200001  67.281998  49297000.0  67.281998
#
#             Total Traded
# Date
# 2018-01-02  1.357886e+09
# 2018-01-03  1.451401e+09
# 2018-01-04  3.111899e+09
# 2018-01-05  1.453666e+09
# 2018-01-08  3.115570e+09

# %%
toyota.head()
# Out:
#                   High         Low        Open       Close  Volume  \
# Date
# 2018-01-02  128.429993  127.169998  127.430000  128.369995   83500
# 2018-01-03  130.240005  128.559998  128.679993  130.130005  162200
# 2018-01-04  132.160004  131.300003  131.309998  132.160004  161800
# 2018-01-05  133.869995  133.080002  133.110001  133.860001  135300
# 2018-01-08  134.789993  133.619995  133.979996  134.770004  131200
#
#              Adj Close  Total Traded
# Date
# 2018-01-02  128.369995  1.064041e+07
# 2018-01-03  130.130005  2.087189e+07
# 2018-01-04  132.160004  2.124596e+07
# 2018-01-05  133.860001  1.800978e+07
# 2018-01-08  134.770004  1.757818e+07

# %%
gm.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2018-01-02  41.869999  41.150002  41.240002  41.799999   6934600.0  38.072212
# 2018-01-03  42.950001  42.200001  42.209999  42.820000  14591600.0  39.001247
# 2018-01-04  44.250000  43.009998  43.090000  44.139999  17298700.0  40.203522
# 2018-01-05  44.639999  43.959999  44.500000  44.009998   9643300.0  40.085117
# 2018-01-08  44.590000  43.520000  44.040001  44.220001  13099600.0  40.276390
#
#             Total Traded
# Date
# 2018-01-02  2.859829e+08
# 2018-01-03  6.159114e+08
# 2018-01-04  7.454010e+08
# 2018-01-05  4.291268e+08
# 2018-01-08  5.769064e+08

# %%
# This will plot the total amount of trade for each company
#Comparing the total trade for each of the companies and create the plot
tesla['Total Traded'].plot(label='Tesla',figsize=(17,10))
toyota['Total Traded'].plot(label='Toyota')
gm['Total Traded'].plot(label='GM')
plt.ylabel('Total Traded')
plt.title('Total Trade for Tesla, GM and Toyota')
plt.legend() # To put a legend for it
plt.show()

# %%
# to get the max for Tesla Traded
tesla['Total Traded'].argmax()
# Out:
# 747

# %%
# to get the max for Toyota Traded
toyota['Total Traded'].argmax()
# Out:
# 782

# %%
# to get the max for GM Traded
gm['Total Traded'].argmax()
# Out:
# 903

# %%
# using iLoc to find the date for the max total trade for Tesla
tesla.iloc[[tesla['Total Traded'].argmax()]]
# Out:
#              High         Low        Open  Close       Volume  Adj Close  \
# Date
# 2020-12-18  695.0  628.539978  668.900024  695.0  222126200.0      695.0
#
#             Total Traded
# Date
# 2020-12-18  1.485802e+11

# %%
# using iLoc to find the date for the max total trade for Tesla
toyota.iloc[[toyota['Total Traded'].argmax()]]
# Out:
#                   High         Low   Open       Close   Volume   Adj Close  \
# Date
# 2021-02-10  163.369995  155.610001  156.0  161.559998  1415500  161.559998
#
#             Total Traded
# Date
# 2021-02-10   220818000.0

# %%
# using iLoc to find the date for the max total trade for Tesla
gm.iloc[[gm['Total Traded'].argmax()]]
# Out:
#                  High        Low   Open      Close      Volume  Adj Close  \
# Date
# 2021-08-04  55.450001  52.209999  55.23  52.720001  67667200.0  52.720001
#
#             Total Traded
# Date
# 2021-08-04  3.737259e+09

# %%
# Creating a moving average to make data more robust
# This will compare the open price using basic plot and the moving average of 50 and 100 for Tesla
tesla['Open'].plot(label='Tesla Original with no Moving Average',figsize=(17,10))
tesla['MA50'] = tesla['Open'].rolling(50).mean()
tesla['MA50'].plot(label = 'MA50')
tesla['MA100'] = tesla['Open'].rolling(100).mean()
tesla['MA100'].plot(label = 'MA100')
plt.ylabel('Open Prices for Tesla')
plt.title('Comparing using moving Average')
plt.legend() # To put a legend for it
plt.show()

# %%
from pandas.plotting import scatter_matrix
import pandas as pd

# %%
car_comp = pd.concat([tesla['Open'],toyota['Open'],gm['Open']],axis=1)
car_comp.columns = ['Tesla Open', 'GM Open', 'Toyota Open']

# %%
#creating Scatter matrix
scatter_matrix(car_comp,figsize=(10,10), hist_kwds={'bins' : 50})
# Out:
# array([[<AxesSubplot:xlabel='Tesla Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='Toyota Open', ylabel='Tesla Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='Toyota Open', ylabel='GM Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='Toyota Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Toyota Open'>,
#         <AxesSubplot:xlabel='Toyota Open', ylabel='Toyota Open'>]],
#       dtype=object)
